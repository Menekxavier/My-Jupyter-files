# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Ekemini Augustine/Downloads/test13.csv')
df
# Out:
#        Unnamed: 0.1  Unnamed: 0             DateTime  Junction  \
# 0                 0           0  2015-11-01 00:00:00         1
# 1                 1           1  2015-11-01 01:00:00         1
# 2                 2           2  2015-11-01 02:00:00         1
# 3                 3           3  2015-11-01 03:00:00         1
# 4                 4           4  2015-11-01 04:00:00         1
# ...             ...         ...                  ...       ...
# 48115         48115       48115  2017-06-30 19:00:00         4
# 48116         48116       48116  2017-06-30 20:00:00         4
# 48117         48117       48117  2017-06-30 21:00:00         4
# 48118         48118       48118  2017-06-30 22:00:00         4
# 48119         48119       48119  2017-06-30 23:00:00         4
#
#        Num.of.veh.at.that.hr.           ID  Congested
# 0                          15  20151101001          1
# 1                          13  20151101011          1
# ...

# %%
def update_congestion(value):
    if value > 10:
        return

# %%
df['Congested'] = df['Num.of.veh.at.that.hr.'].apply(update_congestion)

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0             DateTime  Junction  \
# 0                 0           0  2015-11-01 00:00:00         1
# 1                 1           1  2015-11-01 01:00:00         1
# 2                 2           2  2015-11-01 02:00:00         1
# 3                 3           3  2015-11-01 03:00:00         1
# 4                 4           4  2015-11-01 04:00:00         1
# ...             ...         ...                  ...       ...
# 48115         48115       48115  2017-06-30 19:00:00         4
# 48116         48116       48116  2017-06-30 20:00:00         4
# 48117         48117       48117  2017-06-30 21:00:00         4
# 48118         48118       48118  2017-06-30 22:00:00         4
# 48119         48119       48119  2017-06-30 23:00:00         4
#
#        Num.of.veh.at.that.hr.           ID Congested
# 0                          15  20151101001       Yes
# 1                          13  20151101011       Yes
# ...

# %%
df.to_csv('test16.csv')
