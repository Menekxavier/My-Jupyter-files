# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Ekemini Augustine/Downloads/test13.csv')
df
# Out:
#        Unnamed: 0             DateTime  Junction  Num.of.veh.at.that.hr.  \
# 0               0  2015-11-01 00:00:00         1                      15
# 1               1  2015-11-01 01:00:00         1                      13
# 2               2  2015-11-01 02:00:00         1                      10
# 3               3  2015-11-01 03:00:00         1                       7
# 4               4  2015-11-01 04:00:00         1                       9
# ...           ...                  ...       ...                     ...
# 48115       48115  2017-06-30 19:00:00         4                      11
# 48116       48116  2017-06-30 20:00:00         4                      30
# 48117       48117  2017-06-30 21:00:00         4                      16
# 48118       48118  2017-06-30 22:00:00         4                      22
# 48119       48119  2017-06-30 23:00:00         4                      12
#
#                 ID  Congested
# 0      20151101001          1
# ...

# %%
miss = df.isnull().sum()
miss
# Out:
# Unnamed: 0                0
# DateTime                  0
# Junction                  0
# Num.of.veh.at.that.hr.    0
# ID                        0
# Congested                 0
# dtype: int64

# %%
miss.to_csv('test14.csv')
