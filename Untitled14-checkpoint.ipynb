# %%
import pandas as pdupdatecongestion

# %%
df = pd.read_csv('C:/Users/Ekemini Augustine/Downloads/test16.csv')
df
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0             DateTime  Junction  \
# 0                 0             0           0  2015-11-01 00:00:00         1
# 1                 1             1           1  2015-11-01 01:00:00         1
# 2                 2             2           2  2015-11-01 02:00:00         1
# 3                 3             3           3  2015-11-01 03:00:00         1
# 4                 4             4           4  2015-11-01 04:00:00         1
# ...             ...           ...         ...                  ...       ...
# 48115         48115         48115       48115  2017-06-30 19:00:00         4
# 48116         48116         48116       48116  2017-06-30 20:00:00         4
# 48117         48117         48117       48117  2017-06-30 21:00:00         4
# 48118         48118         48118       48118  2017-06-30 22:00:00         4
# 48119         48119         48119       48119  2017-06-30 23:00:00         4
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0.2               int64
# Unnamed: 0.1               int64
# Unnamed: 0                 int64
# DateTime                  object
# Junction                   int64
# Num.of.veh.at.that.hr.     int64
# ID                         int64
# Congested                 object
# dtype: object

# %%
#All the column are in it's appropriate datatype
